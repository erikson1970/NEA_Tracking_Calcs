# %% [markdown]
# ```
# https://www.changpuak.ch/electronics/yagi_uda_antenna.php
# Javascript Version 12.01.2014, based on Rothammel / DL6WU
# -------------------------------------------------------------
# Frequency     :  1420  MHz, (useful from 1391.6 to 1448.4)
# Wavelength    :  211  mm
# Rod Diameter  :  2  mm
# Boom Diameter :  51  mm
# Boom Length   :  858  mm
# d/lambda      :  0.009    ( min.: 0.002 , max.: 0.01 )
# D/lambda      :  0.050    ( min.: 0.01 , max.: 0.05 )
# Elements      :  15
# Gain          :  13.88 dBd (approx.)
# -------------------------------------------------------------
# Reflector Length   : 102 mm
# Reflector Position :  0 mm
# -------------------------------------------------------------
# Dipole Position    : 51 mm
# -------------------------------------------------------------
# Director #1 Position : 67 mm ,  Length : 96 mm
# Distance Dipole - Dir. #1 : 16 mm
# -------------------------------------------------------------
# Director #2 Position : 105 mm ,  Length : 95 mm
# Distance Dir. #1 - Dir. #2 : 38 mm
# -------------------------------------------------------------
# Director #3 Position : 150 mm ,  Length : 94 mm
# Distance Dir. #2 - Dir. #3 : 45 mm
# -------------------------------------------------------------
# Director #4 Position : 203 mm ,  Length : 94 mm
# Distance Dir. #3 - Dir. #4 : 53 mm
# -------------------------------------------------------------
# Director #5 Position : 262 mm ,  Length : 93 mm
# Distance Dir. #4 - Dir. #5 : 59 mm
# -------------------------------------------------------------
# Director #6 Position : 325 mm ,  Length : 92 mm
# Distance Dir. #5 - Dir. #6 : 63 mm
# -------------------------------------------------------------
# Director #7 Position : 392 mm ,  Length : 92 mm
# Distance Dir. #6 - Dir. #7 : 67 mm
# -------------------------------------------------------------
# Director #8 Position : 462 mm ,  Length : 91 mm
# Distance Dir. #7 - Dir. #8 : 70 mm
# -------------------------------------------------------------
# Director #9 Position : 535 mm ,  Length : 91 mm
# Distance Dir. #8 - Dir. #9 : 73 mm
# -------------------------------------------------------------
# Director #10 Position : 611 mm ,  Length : 90 mm
# Distance Dir. #9 - Dir. #10 : 76 mm
# -------------------------------------------------------------
# Director #11 Position : 690 mm ,  Length : 90 mm
# Distance Dir. #10 - Dir. #11 : 79 mm
# -------------------------------------------------------------
# Director #12 Position : 771 mm ,  Length : 90 mm
# Distance Dir. #11 - Dir. #12 : 81 mm
# -------------------------------------------------------------
# Director #13 Position : 854 mm ,  Length : 89 mm
# Distance Dir. #12 - Dir. #13 : 82 mm
# -------------------------------------------------------------
# Directors / Parasitics are isolated.
# Please choose an isolater thicker than : 5 mm
# ```
